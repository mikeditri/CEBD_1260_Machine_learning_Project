# %%
import numpy as np   
import pandas as pd  
import os
import gc
import seaborn as sns  # for plotting graphs
import matplotlib.pyplot as plt # for plotting graphs aswell
import glob
from datetime import datetime
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestClassifier
# %matplotlib inline
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
def dtype_conver(Dataframe):
    for col in Dataframe:
        if Dataframe[col].dtype == 'float':
            Dataframe[col] = Dataframe[col].astype(np.float16)
        if Dataframe[col].dtype == 'int64':
            Dataframe[col] = Dataframe[col].astype(np.int16)

# %%
def mem_use(Dataframe):
    mem_use = Dataframe.memory_usage().sum() / 1024 ** 3  # this data set takes >1.7G RAM, we should optimize it after
    print('Memory usage of dataframe is {:.2f} GB'.format(mem_use))

# %%
DATA_PATH = '/Users/m_ditri/Downloads/CEBD_1260_Machine_learning_Project-master/'
file_name = os.path.join(DATA_PATH,'train-3.csv')

# %%
train_df = pd.read_csv(file_name)
print(train_df.shape)
# Out:
# (260753, 299)

# %%
dtype_conver(train_df)

# %%
mem_use = train_df.memory_usage().sum() / 1024 ** 3  # this data set takes >1.7G RAM, we should optimize it after
print('Memory usage of dataframe is {:.2f} GB'.format(mem_use))
# Out:
# Memory usage of dataframe is 0.19 GB

# %%
nan_info = pd.DataFrame(train_df.isnull().sum()).reset_index()
nan_info.columns = ['col','nan_cnt']
nan_info.sort_values(by = 'nan_cnt',ascending=False,inplace=True)
nan_info
# Out:
#                       col  nan_cnt
# 161       PropertyField29   200685
# 125       PersonalField84   124208
# 170       PropertyField38     1220
# 49         PersonalField7      113
# 168       PropertyField36      113
# 130        PropertyField3       81
# 166       PropertyField34       70
# 164       PropertyField32       70
# 131        PropertyField4       63
# 198    GeographicField13B        0
# 197    GeographicField13A        0
# 199    GeographicField14A        0
# 200    GeographicField14B        0
# 207    GeographicField18A        0
# 201    GeographicField15A        0
# 196    GeographicField12B        0
# 202    GeographicField15B        0
# 195    GeographicField12A        0
# 203    GeographicField16A        0
# 194    GeographicField11B        0
# 204    GeographicField16B        0
# 205    GeographicField17A        0
# 193    GeographicField11A        0
# 206    GeographicField17B        0
# 0             QuoteNumber        0
# 208    GeographicField18B        0
# 216    GeographicField22B        0
# 222    GeographicField25B        0
# 221    GeographicField25A        0
# 220    GeographicField24B        0
# 219    GeographicField24A        0
# 218    GeographicField23B        0
# 217    GeographicField23A        0
# 215    GeographicField22A        0
# 209    GeographicField19A        0
# 214    GeographicField21B        0
# 213    GeographicField21A        0
# 212    GeographicField20B        0
# 211    GeographicField20A        0
# 210    GeographicField19B        0
# 191    GeographicField10A        0
# 192    GeographicField10B        0
# 187     GeographicField8A        0
# 190     GeographicField9B        0
# 173     GeographicField1A        0
# 154      PropertyField24A        0
# 155      PropertyField24B        0
# 156       PropertyField25        0
# 157      PropertyField26A        0
# 158      PropertyField26B        0
# 159       PropertyField27        0
# 160       PropertyField28        0
# 162       PropertyField30        0
# 163       PropertyField31        0
# 165       PropertyField33        0
# 167       PropertyField35        0
# 85        PersonalField44        0
# 84        PersonalField43        0
# 83        PersonalField42        0
# 82        PersonalField41        0
# 81        PersonalField40        0
# 80        PersonalField39        0
# 79        PersonalField38        0
# 78        PersonalField37        0
# 77        PersonalField36        0
# 92        PersonalField51        0
# 93        PersonalField52        0
# 94        PersonalField53        0
# 103       PersonalField62        0
# 109       PersonalField68        0
# 108       PersonalField67        0
# 107       PersonalField66        0
# 106       PersonalField65        0
# 105       PersonalField64        0
# 104       PersonalField63        0
# 102       PersonalField61        0
# 95        PersonalField54        0
# 101       PersonalField60        0
# 100       PersonalField59        0
# 99        PersonalField58        0
# 98        PersonalField57        0
# 97        PersonalField56        0
# 96        PersonalField55        0
# 298     GeographicField64        0

# %%
cols_with_missing = nan_info.loc[nan_info.nan_cnt>0].col.values
cols_with_missing
# Out:
# array(['PropertyField29', 'PersonalField84', 'PropertyField38',
#        'PersonalField7', 'PropertyField36', 'PropertyField3',
#        'PropertyField34', 'PropertyField32', 'PropertyField4'],
#       dtype=object)

# %%
train_df['PropertyField29'].fillna(-1,inplace=True)
train_df['PersonalField84'].fillna(-1,inplace=True)
train_df['PropertyField38'].fillna(-1,inplace=True)
train_df['PersonalField7'].fillna(-1,inplace=True)
train_df['PropertyField3'].fillna(-1,inplace=True)
train_df['PropertyField34'].fillna(-1,inplace=True)
train_df['PropertyField32'].fillna(-1,inplace=True)
train_df['PropertyField4'].fillna(-1,inplace=True)
train_df['PropertyField36'].fillna(-1,inplace=True)

# %%
# define target
y = train_df["QuoteConversion_Flag"].values

# drop target column from data
X = train_df.drop(["QuoteConversion_Flag"], axis = 1)

#QuoteNumber setting as index
X = X.set_index("QuoteNumber")

# %%
#select all numerical columns, then check if each column is indeed numerical
numerical_cols = [cols for cols in X.columns if train_df[cols].dtype in['int8','int16','int32','int64','float16',
                                                                               'float32','float64']]
#get min value of each numerical comlumn
minimum = X[numerical_cols].min().values

#get max value of each numerical comlumn
maximum = X[numerical_cols].max().values

#get number of nuniques per column
nuniques = X[numerical_cols].nunique().values

#display all rows
pd.set_option('display.max_rows', None)

#build dataframe of column min and max values using a directory
num_df = pd.DataFrame({'columns' :numerical_cols, 'min' :minimum, 'max' :maximum, 'nuniques' :nuniques})

# %%
# %%time
train_df['pick_uplongitude_r2'] = train_df['pickup_longitude'].apply(lambda x:round(x,2))

# %%
#replace get dummies with label encoder

for col in X.columns:
    if col not in ['SaleField8','Original_Quote_Date']:
        temp_df = pd.get_dummies(X[col],prefix=X[col])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-872407f19050> in <module>
#       1 for col in X.columns:
#       2     if col not in ['SaleField8','Original_Quote_Date']:
# ----> 3         temp_df = pd.get_dummies(X[col],prefix=X[col])
#       4
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     864                                  sparse=sparse,
#     865                                  drop_first=drop_first,
# --> 866                                  dtype=dtype)
#     867     return result
#     868
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#     919
#     920         dummy_cols = [_make_col_name(prefix, prefix_sep, level)
# --> 921                       for level in levels]
#     922
#     923     if isinstance(data, Series):
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in <listcomp>(.0)
#     919
#     920         dummy_cols = [_make_col_name(prefix, prefix_sep, level)
# --> 921                       for level in levels]
#     922
#     923     if isinstance(data, Series):
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in _make_col_name(prefix, prefix_sep, level)
#     916             return fstr.format(prefix=prefix,
#     917                                prefix_sep=prefix_sep,
# --> 918                                level=level)
#     919
#     920         dummy_cols = [_make_col_name(prefix, prefix_sep, level)
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in __str__(self)
#      55
#      56         if compat.PY3:
# ---> 57             return self.__unicode__()
#      58         return self.__bytes__()
#      59
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __unicode__(self)
#    1381
#    1382         self.to_string(buf=buf, name=self.name, dtype=self.dtype,
# -> 1383                        max_rows=max_rows, length=show_dimensions)
#    1384         result = buf.getvalue()
#    1385
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows)
#    1425                                         float_format=float_format,
#    1426                                         max_rows=max_rows)
# -> 1427         result = formatter.to_string()
#    1428
#    1429         # catch contract violations
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in to_string(self)
#     263             return 'Series([], ' + footer + ')'
#     264
# --> 265         fmt_index, have_header = self._get_formatted_index()
#     266         fmt_values = self._get_formatted_values()
#     267
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in _get_formatted_index(self)
#     248         else:
#     249             have_header = index.name is not None
# --> 250             fmt_index = index.format(name=True)
#     251         return fmt_index, have_header
#     252
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in format(self, name, formatter, **kwargs)
#     994             return header + list(self.map(formatter))
#     995
# --> 996         return self._format_with_header(header, **kwargs)
#     997
#     998     def _format_with_header(self, header, na_rep='NaN', **kwargs):
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _format_with_header(self, header, na_rep, **kwargs)
#    1019
#    1020         else:
# -> 1021             result = _trim_front(format_array(values, None, justify='left'))
#    1022         return header + result
#    1023
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#     905                         leading_space=leading_space)
#     906
# --> 907     return fmt_obj.get_result()
#     908
#     909
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in get_result(self)
#     926
#     927     def get_result(self):
# --> 928         fmt_values = self._format_strings()
#     929         return _make_fixed_width(fmt_values, self.justify)
#     930
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in _format_strings(self)
#    1138     def _format_strings(self):
#    1139         formatter = self.formatter or (lambda x: '{x: d}'.format(x=x))
# -> 1140         fmt_values = [formatter(x) for x in self.values]
#    1141         return fmt_values
#    1142
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    1138     def _format_strings(self):
#    1139         formatter = self.formatter or (lambda x: '{x: d}'.format(x=x))
# -> 1140         fmt_values = [formatter(x) for x in self.values]
#    1141         return fmt_values
#    1142
#
# /Users/kingf00/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in <lambda>(x)
#    1137
#    1138     def _format_strings(self):
# -> 1139         formatter = self.formatter or (lambda x: '{x: d}'.format(x=x))
#    1140         fmt_values = [formatter(x) for x in self.values]
#    1141         return fmt_values
#
# KeyboardInterrupt:

# %%
# let us concat the newly generated on-hot feature on the main table
train_df = pd.concat([train_df,temp_df],axis=1)
train_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-be85eaa12f78> in <module>
# ----> 1 temp_df
#
# NameError: name 'temp_df' is not defined

# %%
#always separate test data from the rest
X_rem,X_test,y_rem,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

#separate validation data from training data
X_train,X_val,y_train,y_val = train_test_split(X_rem,y_rem,test_size=0.25,random_state=1)

# %%
#feature selection (dont need right now, just for final project), cross validation 5-fold) then train randomn forest
